# %% [markdown]
# # Recommender System (Part 1)

# %% [markdown]
# ## Recommendation Based on Popularity

# %% [markdown]
# In this section, I will create a recommendation engine based only on the popularity of films. The popularity metric I will be using is IMDB's weighted rating formula.
#
#
# Weighted Rating (WR) = (v/v+m)*R + (m/v+m)*C
#
# where, v = Number of votes for the movie
#         m = minimum votes requred to be listed in the chart
#         R = Average rating of the movie
#         C = Mean votes.
#
#
# This is a system that is not personalized based on a user or an item. This is neither content based nor collaborative based. It is just a simple system that uses popularity metric to suggest films.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from ast import literal_eval

# %%
data = pd.read_csv("movies_metadata.csv")
data.shape
data.head(20)
# Out:
# C:\Users\Shoum\Anaconda3\envs\newenv\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...         0
# 13  False                                                NaN  44000000
# 14  False                                                NaN  98000000
# 15  False                                                NaN  52000000
# 16  False                                                NaN  16500000
# 17  False                                                NaN   4000000
# 18  False  {'id': 3167, 'name': 'Ace Ventura Collection',...  30000000
# 19  False                                                NaN  60000000
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                      [{'id': 35, 'name': 'Comedy'}]
# 5   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 6   [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 7   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 10  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 11  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 12  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 13  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 16  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 17  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 18  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 19  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                                         homepage     id    imdb_id  \
# 0           http://toystory.disney.com/toy-story    862  tt0114709
# 1                                            NaN   8844  tt0113497
# 2                                            NaN  15602  tt0113228
# 3                                            NaN  31357  tt0114885
# 4                                            NaN  11862  tt0113041
# 5                                            NaN    949  tt0113277
# 6                                            NaN  11860  tt0114319
# 7                                            NaN  45325  tt0112302
# 8                                            NaN   9091  tt0114576
# 9   http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
# 10                                           NaN   9087  tt0112346
# 11                                           NaN  12110  tt0112896
# 12                                           NaN  21032  tt0112453
# 13                                           NaN  10858  tt0113987
# 14                                           NaN   1408  tt0112760
# 15                                           NaN    524  tt0112641
# 16                                           NaN   4584  tt0114388
# 17                                           NaN      5  tt0113101
# 18                                           NaN   9273  tt0112281
# 19                                           NaN  11517  tt0113845
#
#    original_language                  original_title  \
# 0                 en                       Toy Story
# 1                 en                         Jumanji
# 2                 en                Grumpier Old Men
# 3                 en               Waiting to Exhale
# 4                 en     Father of the Bride Part II
# 5                 en                            Heat
# 6                 en                         Sabrina
# 7                 en                    Tom and Huck
# 8                 en                    Sudden Death
# 9                 en                       GoldenEye
# 10                en          The American President
# 11                en     Dracula: Dead and Loving It
# 12                en                           Balto
# 13                en                           Nixon
# 14                en                Cutthroat Island
# 15                en                          Casino
# 16                en           Sense and Sensibility
# 17                en                      Four Rooms
# 18                en  Ace Ventura: When Nature Calls
# 19                en                     Money Train
#
#                                              overview  ... release_date  \
# 0   Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1   When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2   A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3   Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4   Just when George Banks has recovered from his ...  ...   1995-02-10
# 5   Obsessive master thief, Neil McCauley leads a ...  ...   1995-12-15
# 6   An ugly duckling having undergone a remarkable...  ...   1995-12-15
# 7   A mischievous young boy, Tom Sawyer, witnesses...  ...   1995-12-22
# 8   International action superstar Jean Claude Van...  ...   1995-12-22
# 9   James Bond must unmask the mysterious head of ...  ...   1995-11-16
# 10  Widowed U.S. president Andrew Shepherd, one of...  ...   1995-11-17
# 11  When a lawyer shows up at the vampire's doorst...  ...   1995-12-22
# 12  An outcast half-wolf risks his life to prevent...  ...   1995-12-22
# 13  An all-star cast powers this epic look at Amer...  ...   1995-12-22
# 14  Morgan Adams and her slave, William Shaw, are ...  ...   1995-12-22
# 15  The life of the gambling paradise – Las Vegas ...  ...   1995-11-22
# 16  Rich Mr. Dashwood dies, leaving his second wif...  ...   1995-12-13
# 17  It's Ted the Bellhop's first night on the job....  ...   1995-12-09
# 18  Summoned from an ashram in Tibet, Ace finds hi...  ...   1995-11-10
# 19  A vengeful New York transit cop decides to ste...  ...   1995-11-21
#
#         revenue runtime                                   spoken_languages  \
# 0   373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1   262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2           0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3    81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4    76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5   187436818.0   170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 6           0.0   127.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 7           0.0    97.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 8    64350171.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9   352194034.0   130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 10  107879496.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 11          0.0    88.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 12   11348324.0    78.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 13   13681765.0   192.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 14   10017322.0   119.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 15  116112375.0   178.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 16  135000000.0   136.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 17    4300000.0    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 18  212385533.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 19   35431113.0   103.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#       status                                            tagline  \
# 0   Released                                                NaN
# 1   Released          Roll the dice and unleash the excitement!
# 2   Released  Still Yelling. Still Fighting. Still Ready for...
# 3   Released  Friends are the people who let you be yourself...
# 4   Released  Just When His World Is Back To Normal... He's ...
# 5   Released                           A Los Angeles Crime Saga
# 6   Released  You are cordially invited to the most surprisi...
# 7   Released                             The Original Bad Boys.
# 8   Released                         Terror goes into overtime.
# 9   Released               No limits. No fears. No substitutes.
# 10  Released  Why can't the most powerful man in the world h...
# 11  Released                                                NaN
# 12  Released                     Part Dog. Part Wolf. All Hero.
# 13  Released  Triumphant in Victory, Bitter in Defeat. He Ch...
# 14  Released  The Course Has Been Set. There Is No Turning B...
# 15  Released                   No one stays at the top forever.
# 16  Released           Lose your heart and come to your senses.
# 17  Released  Twelve outrageous guests. Four scandalous requ...
# 18  Released            New animals. New adventures. Same hair.
# 19  Released                        Get on, or GET OUT THE WAY!
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# 5                             Heat  False          7.7     1886.0
# 6                          Sabrina  False          6.2      141.0
# 7                     Tom and Huck  False          5.4       45.0
# 8                     Sudden Death  False          5.5      174.0
# 9                        GoldenEye  False          6.6     1194.0
# 10          The American President  False          6.5      199.0
# 11     Dracula: Dead and Loving It  False          5.7      210.0
# 12                           Balto  False          7.1      423.0
# 13                           Nixon  False          7.1       72.0
# 14                Cutthroat Island  False          5.7      137.0
# 15                          Casino  False          7.8     1343.0
# 16           Sense and Sensibility  False          7.2      364.0
# 17                      Four Rooms  False          6.5      539.0
# 18  Ace Ventura: When Nature Calls  False          6.1     1128.0
# 19                     Money Train  False          5.4      224.0
#
# [20 rows x 24 columns]

# %%
data['genres'] = data['genres'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
#Vote counts
vote_counts = data[data['vote_count'].notnull()]['vote_count'].astype('int')

# Lets choose m to be 95 %ile
m = vote_counts.quantile(0.95)

#Vote average
vote_average = data[data['vote_average'].notnull()]['vote_average'].astype('int')

# Mean vote average
C = vote_average.mean()

# %%
data['year'] = data['release_date'].apply(lambda x: str(x).split('-')[0])
data['year']
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
#          ...
# 45461     nan
# 45462    2011
# 45463    2003
# 45464    1917
# 45465    2017
# Name: year, Length: 45466, dtype: object

# %% [markdown]
# We keep only those movies where vote counts are not null, vote counts are greater than 95%ile and vote averages are not null. We create a new data frame called "qualified"

# %%
qualified = data[(data['vote_count'] >=m) & (data['vote_count'].notnull()) & (data['vote_average'].notnull())][['title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres']]

qualified['vote_count'] = qualified['vote_count'].astype('int')

qualified['vote_average'] = qualified['vote_average'].astype('int')

# %%
#Applying formula
def weighted_rating(x):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
qualified['wr'] = qualified.apply(weighted_rating, axis=1)

# %%
qualified = qualified.sort_values('wr', ascending = False).head(250)
qualified.head(10)
# Out:
#                                                    title  year  vote_count  \
# 15480                                          Inception  2010       14075
# 12481                                    The Dark Knight  2008       12269
# 22879                                       Interstellar  2014       11187
# 2843                                          Fight Club  1999        9678
# 4863   The Lord of the Rings: The Fellowship of the Ring  2001        8892
# 292                                         Pulp Fiction  1994        8670
# 314                             The Shawshank Redemption  1994        8358
# 7000       The Lord of the Rings: The Return of the King  2003        8226
# 351                                         Forrest Gump  1994        8147
# 5814               The Lord of the Rings: The Two Towers  2002        7641
#
#        vote_average popularity  \
# 15480             8    29.1081
# 12481             8    123.167
# 22879             8    32.2135
# 2843              8    63.8696
# 4863              8    32.0707
# 292               8     140.95
# 314               8    51.6454
# 7000              8    29.3244
# 351               8    48.3072
# 5814              8    29.4235
#
#                                                   genres        wr
# 15480  [Action, Thriller, Science Fiction, Mystery, A...  7.917588
# 12481                   [Drama, Action, Crime, Thriller]  7.905871
# 22879                [Adventure, Drama, Science Fiction]  7.897107
# 2843                                             [Drama]  7.881753
# 4863                        [Adventure, Fantasy, Action]  7.871787
# 292                                    [Thriller, Crime]  7.868660
# 314                                       [Drama, Crime]  7.864000
# 7000                        [Adventure, Fantasy, Action]  7.861927
# 351                             [Comedy, Drama, Romance]  7.860656
# 5814                        [Adventure, Fantasy, Action]  7.851924

# %% [markdown]
# ## Popular Movies Based on a Genre

# %%
s = data.apply(lambda x: pd.Series(x['genres']),axis=1).stack().reset_index(level=1, drop=True)
s.head(10)
# Out:
# C:\Users\Shoum\Anaconda3\envs\newenv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.
# 0    Animation
# 0       Comedy
# 0       Family
# 1    Adventure
# 1      Fantasy
# 1       Family
# 2      Romance
# 2       Comedy
# 3       Comedy
# 3        Drama
# dtype: object

# %%
s.name = 'genre'
gen_md = data.drop('genres',axis = 1).join(s)

# %%
def build_chart(genre, percentile = 0.85):
    df = gen_md[gen_md['genre'] == genre]
    vote_avg = df[df['vote_average'].notnull()]['vote_average'].astype('int')
    C = vote_avg.mean()
    
    vote_ct = df[df['vote_count'].notnull()]['vote_count'].astype('int')
    m = vote_ct.quantile(percentile)
    
    qualified = df[(df['vote_count'] >= m) & (df['vote_average'].notnull()) & (df['vote_count'].notnull())][['title', 'year', 'vote_count', 'vote_average', 'popularity']]
    
    qualified['wr'] = qualified.apply(lambda x: (x['vote_count']/(x['vote_count']+m) * x['vote_average']) + (m/(m+x['vote_count']) * C), axis=1)
    qualified = qualified.sort_values('wr', ascending=False).head(250)
    
    return qualified

# %%
rom = build_chart('Romance')
rom.head(10)
# Out:
#                                        title  year  vote_count  vote_average  \
# 10309            Dilwale Dulhania Le Jayenge  1995       661.0           9.1
# 40251                             Your Name.  2016      1030.0           8.5
# 351                             Forrest Gump  1994      8147.0           8.2
# 1132                         Cinema Paradiso  1988       834.0           8.2
# 40882                             La La Land  2016      4745.0           7.9
# 22168                                    Her  2013      4215.0           7.9
# 7208   Eternal Sunshine of the Spotless Mind  2004      3758.0           7.9
# 876                                  Vertigo  1958      1162.0           8.0
# 15530                             Mr. Nobody  2009      1616.0           7.9
# 38798                      Captain Fantastic  2016      1569.0           7.9
#
#       popularity        wr
# 10309     34.457  8.653196
# 40251  34.461252  8.248941
# 351      48.3072  8.169150
# 1132      14.177  7.925222
# 40882  19.681686  7.853086
# 22168    13.8295  7.847311
# 7208     12.9063  7.841055
# 876      18.2082  7.811667
# 15530    11.8171  7.767085
# 38798  16.519276  7.763322

# %%
act = build_chart("Action")
act.head(10)
# Out:
#                                                    title  year  vote_count  \
# 12481                                    The Dark Knight  2008     12269.0
# 1154                             The Empire Strikes Back  1980      5998.0
# 15480                                          Inception  2010     14075.0
# 7000       The Lord of the Rings: The Return of the King  2003      8226.0
# 256                                            Star Wars  1977      6778.0
# 4863   The Lord of the Rings: The Fellowship of the Ring  2001      8892.0
# 5814               The Lord of the Rings: The Two Towers  2002      7641.0
# 23753                            Guardians of the Galaxy  2014     10014.0
# 2458                                          The Matrix  1999      9079.0
# 13605                               Inglourious Basterds  2009      6598.0
#
#        vote_average popularity        wr
# 12481           8.3    123.167  8.243159
# 1154            8.2     19.471  8.089546
# 15480           8.1    29.1081  8.053512
# 7000            8.1    29.3244  8.021345
# 256             8.1    42.1497  8.005086
# 4863            8.0    32.0707  7.929579
# 5814            8.0    29.4235  7.918382
# 23753           7.9    53.2916  7.839511
# 2458            7.9    33.3663  7.833434
# 13605           7.9    16.8956  7.809236

# %%
fan = build_chart('Fantasy')
fan.head(10)
# Out:
#                                                    title  year  vote_count  \
# 5481                                       Spirited Away  2001      3968.0
# 7000       The Lord of the Rings: The Return of the King  2003      8226.0
# 3030                                      The Green Mile  1999      4166.0
# 4863   The Lord of the Rings: The Fellowship of the Ring  2001      8892.0
# 5814               The Lord of the Rings: The Two Towers  2002      7641.0
# 17437       Harry Potter and the Deathly Hallows: Part 2  2011      6141.0
# 9698                                Howl's Moving Castle  2004      2049.0
# 2884                                   Princess Mononoke  1997      2041.0
# 7725            Harry Potter and the Prisoner of Azkaban  2004      6037.0
# 10839                                     V for Vendetta  2006      4562.0
#
#        vote_average popularity        wr
# 5481            8.3    41.0489  8.034694
# 7000            8.1    29.3244  7.974898
# 3030            8.2    19.9668  7.954879
# 4863            8.0    32.0707  7.888126
# 5814            8.0    29.4235  7.870711
# 17437           7.9    24.9907  7.747091
# 9698            8.2     16.136  7.742589
# 2884            8.2    17.1667  7.741087
# 7725            7.7    28.4603  7.556913
# 10839           7.7    20.2144  7.514339

# %% [markdown]
# ## Most Popular higher rated movies

# %%
worstpop = data.loc[data['popularity'].notnull()][['title', 'year', 'vote_count', 'vote_average', 'popularity']]
worstpop['popularity']
# Out:
# 0         21.9469
# 1         17.0155
# 2         11.7129
# 3         3.85949
# 4         8.38752
#            ...
# 45461    0.072051
# 45462    0.178241
# 45463    0.903007
# 45464    0.003503
# 45465    0.163015
# Name: popularity, Length: 45461, dtype: object

# %%
def WOrstPop(vote_avg=5):
    df = worstpop[worstpop['vote_average']> vote_avg]
    df['popularity'] = df['popularity'].astype('str')
    df = df.sort_values('popularity',ascending=False)
    return df

# %%
Worst_popular = WOrstPop(5).head(250)
Worst_popular.head(10)
# Out:
# C:\Users\Shoum\Anaconda3\envs\newenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                         title  year  vote_count  vote_average  \
# 34313                       Chameli Ki Shaadi  1986         0.0           0.0
# 38576  Hyper Sapien: People from Another Star  1986         0.0           0.0
# 12488                              Black Dawn  2005        21.0           3.6
# 14043           The Haunting of Molly Hartley  2008        48.0           4.3
# 497                       The Next Karate Kid  1994       202.0           4.8
# 10464                                 The Fog  2005       191.0           3.8
# 24591                    Children of the Corn  2009        45.0           4.3
# 12286                            Pledge This!  2006        34.0           2.7
# 558                                   Chasers  1994        22.0           4.7
# 11445                                  Eragon  2006       990.0           4.9
#
#               popularity
# 34313              9e-06
# 38576              9e-06
# 12488  9.989719000000001
# 14043           9.982123
# 497               9.9697
# 10464  9.929808999999999
# 24591  9.895964999999999
# 12286           9.867616
# 558              9.85327
# 11445           9.851133
